# %%
sub_sauce_nutrition = {
    "머스타드": {'중량 (g)': 21, '열량 (kcal)': 15.3, '단백질 (g)': 1.1, '포화지방 (g)': 0.1, '당류 (g)': 0.2, '나트륨 (mg)': 193},
    "레드 와인 식초": {'중량 (g)': 3.5, '열량 (kcal)': 0.7, '단백질 (g)': 0, '포화지방 (g)': 0, '당류 (g)': 0, '나트륨 (mg)': 0},
    "스모크 바베큐": {'중량 (g)': 21, '열량 (kcal)': 32.8, '단백질 (g)': 0.2, '포화지방 (g)': 0.1, '당류 (g)': 7, '나트륨 (mg)': 132},
    "허니 머스타드": {'중량 (g)': 21, '열량 (kcal)': 38.4, '단백질 (g)': 0.4, '포화지방 (g)': 0.4, '당류 (g)': 6.3, '나트륨 (mg)': 145},
    "스위트 칠리": {'중량 (g)': 21, '열량 (kcal)': 40, '단백질 (g)': 0.1, '포화지방 (g)': 0, '당류 (g)': 9.2, '나트륨 (mg)': 163},
    "스위트 어니언": {'중량 (g)': 21, '열량 (kcal)': 40.1, '단백질 (g)': 0.1, '포화지방 (g)': 0, '당류 (g)': 8.2, '나트륨 (mg)': 81.7},
    "핫 칠리": {'중량 (g)': 21, '열량 (kcal)': 41.8, '단백질 (g)': 0.2, '포화지방 (g)': 0.1, '당류 (g)': 5.3, '나트륨 (mg)': 180},
    "사우스웨스트 치폴레": {'중량 (g)': 21, '열량 (kcal)': 96.5, '단백질 (g)': 0.4, '포화지방 (g)': 1.6, '당류 (g)': 1, '나트륨 (mg)': 160},
    "홀스래디쉬": {'중량 (g)': 21, '열량 (kcal)': 106, '단백질 (g)': 0.3, '포화지방 (g)': 1.6, '당류 (g)': 2.6, '나트륨 (mg)': 152},
    "랜치": {'중량 (g)': 21, '열량 (kcal)': 116, '단백질 (g)': 0.3, '포화지방 (g)': 2.1, '당류 (g)': 0.6, '나트륨 (mg)': 128},
    "올리브 오일": {'중량 (g)': 3.5, '열량 (kcal)': 124, '단백질 (g)': 0, '포화지방 (g)': 2.1, '당류 (g)': 0, '나트륨 (mg)': 0},
    "마요네즈": {'중량 (g)': 21, '열량 (kcal)': 158, '단백질 (g)': 0.3, '포화지방 (g)': 2.8, '당류 (g)': 0.1, '나트륨 (mg)': 98.1}
}

half_sauce_nutrition = {}
for sauce, nutrition in sub_sauce_nutrition.items():
    half_values = {key: value / 2 for key, value in nutrition.items()}
    half_sauce_nutrition[f"{sauce} (1/2)"] = half_values

sub_sauce_nutrition.update(half_sauce_nutrition)

sub_sauce_nutrition
# Out:
# {'머스타드': {'중량 (g)': 21,
#   '열량 (kcal)': 15.3,
#   '단백질 (g)': 1.1,
#   '포화지방 (g)': 0.1,
#   '당류 (g)': 0.2,
#   '나트륨 (mg)': 193},
#  '레드 와인 식초': {'중량 (g)': 3.5,
#   '열량 (kcal)': 0.7,
#   '단백질 (g)': 0,
#   '포화지방 (g)': 0,
#   '당류 (g)': 0,
#   '나트륨 (mg)': 0},
#  '스모크 바베큐': {'중량 (g)': 21,
#   '열량 (kcal)': 32.8,
#   '단백질 (g)': 0.2,
#   '포화지방 (g)': 0.1,
#   '당류 (g)': 7,
#   '나트륨 (mg)': 132},
#  '허니 머스타드': {'중량 (g)': 21,
#   '열량 (kcal)': 38.4,
#   '단백질 (g)': 0.4,
#   '포화지방 (g)': 0.4,
#   '당류 (g)': 6.3,
#   '나트륨 (mg)': 145},
#  '스위트 칠리': {'중량 (g)': 21,
#   '열량 (kcal)': 40,
#   '단백질 (g)': 0.1,
#   '포화지방 (g)': 0,
#   '당류 (g)': 9.2,
#   '나트륨 (mg)': 163},
#  '스위트 어니언': {'중량 (g)': 21,
#   '열량 (kcal)': 40.1,
#   '단백질 (g)': 0.1,
#   '포화지방 (g)': 0,
#   '당류 (g)': 8.2,
#   '나트륨 (mg)': 81.7},
#  '핫 칠리': {'중량 (g)': 21,
#   '열량 (kcal)': 41.8,
#   '단백질 (g)': 0.2,
#   '포화지방 (g)': 0.1,
#   '당류 (g)': 5.3,
#   '나트륨 (mg)': 180},
#  '사우스웨스트 치폴레': {'중량 (g)': 21,
#   '열량 (kcal)': 96.5,
#   '단백질 (g)': 0.4,
# ...
